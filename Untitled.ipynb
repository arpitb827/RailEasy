# %%
import pandas as pd
import matplotlib as plt
from sqlalchemy import create_engine

a={'1':'arpit','2':'bansal'}

data = pd.Series(a)
print data

engine = create_engine('mysql://root:honey@localhost:3306/irctc', echo=False)
f = pd.read_sql_query('SELECT * FROM contact', engine, index_col = 'id')

df = pd.DataFrame(f)
print df.head()
# Out:
# 1     arpit
# 2    bansal
# dtype: object
#      name                email phone_number  \
# id
# 1   Arpit  arpitb827@gmail.com   9012489503
# 2   Arpit   arpit827@gmail.com   9012489503
# 3   Arpit   arpit827@gmail.com   9012489503
# 4   Arpit   arpit827@gmail.com   9012489503
# 5   Arpit   arpit827@gmail.com   9012489503
#
#                                               message        created_date
# id
# 1   Hi ! can you please revise me the route of mtj... 2017-07-13 22:09:54
# 2                                    Hi ! This is new 2017-07-15 16:04:10
# 3                                    Hi ! This is new 2017-07-15 16:04:51
# 4                                    Hi ! This is new 2017-07-15 16:05:26
# 5                                    Hi ! This is new 2017-07-15 16:06:39
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-c96c07c3b604> in <module>()
#      14 print df.head()
#      15
# ---> 16 plt.plot([1,2,3,4])
#      17 plt.ylabel('some numbers')
#      18 plt.show()
#
# AttributeError: 'module' object has no attribute 'plot'

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
